# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import json

# Import the API key
from school_digger_api_key import school_digger_key

# %%
county_dictionary={'Bastrop County': [78602, 78612, 78621, 78650, 78659, 78662, 78953, 78957],
                   'Hays County': [78610, 78619, 78620, 78640, 78666, 78667, 78676, 78737],
                   'Caldwell County': [78616, 78622, 78644, 78648, 78655, 78656, 78661],
                   'Williamson County':[76527, 76530, 76537, 76573, 76574, 76578, 78613, 78615, 78626, 78627, 78628, 78630, 78634, 78642, 78646, 78664, 78673, 78674, 78680, 78681, 78683, 78717, 78729],
                   'Travis County':[78617, 78641, 78645, 78651, 78652, 78653, 78660, 78669, 78691, 78701, 78702, 78703, 78704, 78705, 78708, 78709, 78710, 78711, 78712, 78713, 78714, 78715, 78716, 78718, 78719, 78720, 78721, 78722, 78723, 78724, 78725, 78726, 78727, 78728, 78730, 78731, 78732, 78733, 78734, 78735, 78736, 78738, 78739, 78741, 78742, 78744, 78745, 78746, 78747, 78748, 78749, 78750, 78751, 78752, 78753, 78754, 78755, 78756, 78757, 78758, 78759, 78760, 78761, 78762, 78763, 78764, 78765, 78766, 78767, 78768, 78769]}
zipcode_dictionary= {78602 :{}, 78612 :{}, 78621 :{}, 78650 :{}, 78659 :{}, 78662 :{}, 78953 :{}, 78957 :{}, 78610 :{}, 78619 :{}, 78620 :{}, 78640 :{}, 78666 :{}, 78667 :{}, 
                     78676 :{}, 78737 :{}, 78616 :{}, 78622 :{}, 78644 :{}, 78648 :{}, 78655 :{}, 78656 :{}, 78661 :{}, 76527 :{}, 76530 :{}, 76537 :{}, 76573 :{}, 76574 :{}, 
                     76578 :{}, 78613 :{}, 78615 :{}, 78626 :{}, 78627 :{}, 78628 :{}, 78630 :{}, 78634 :{}, 78642 :{}, 78646 :{}, 78664 :{}, 78673 :{}, 78674 :{}, 78680 :{}, 
                     78681 :{}, 78683 :{}, 78717 :{}, 78729 :{}, 78617 :{}, 78641 :{}, 78645 :{}, 78651 :{}, 78652 :{}, 78653 :{}, 78660 :{}, 78669 :{}, 78691 :{}, 78701 :{}, 
                     78702 :{}, 78703 :{}, 78704 :{}, 78705 :{}, 78708 :{}, 78709 :{}, 78710 :{}, 78711 :{}, 78712 :{}, 78713 :{}, 78714 :{}, 78715 :{}, 78716 :{}, 78718 :{}, 
                     78719 :{}, 78720 :{}, 78721 :{}, 78722 :{}, 78723 :{}, 78724 :{}, 78725 :{}, 78726 :{}, 78727 :{}, 78728 :{}, 78730 :{}, 78731 :{}, 78732 :{}, 78733 :{}, 
                     78734 :{}, 78735 :{}, 78736 :{}, 78738 :{}, 78739 :{}, 78741 :{}, 78742 :{}, 78744 :{}, 78745 :{}, 78746 :{}, 78747 :{}, 78748 :{}, 78749 :{}, 78750 :{}, 
                     78751 :{}, 78752 :{}, 78753 :{}, 78754 :{}, 78755 :{}, 78756 :{}, 78757 :{}, 78758 :{}, 78759 :{}, 78760 :{}, 78761 :{}, 78762 :{}, 78763 :{}, 78764 :{}, 
                     78765 :{}, 78766 :{}, 78767 :{}, 78768 :{}, 78769 :{}}

school_digger_app_id='5a144e6e'
base_url='https://api.schooldigger.com/v2.0/schools?st=TX'


zipcodes=[]
schoolNames=[]
rankMovements=[]
lats=[]
longs=[]
countyNames=[]
rankLevels=[]
averageStandardScores22=[]
averageStandardScores21=[]
ranks22=[]
ranks21=[]
rankStatewidePercentages22=[]
rankStatewidePercentages21=[]

# %%
for zipcode in county_dictionary['Bastrop County']:
    request_url=f'{base_url}&zip={zipcode}&appID={school_digger_app_id}&appKey={school_digger_key}'
    response = requests.get(request_url)
    school_data=(response.json())
    zipcode_dictionary[zipcode]=school_data
print(json.dumps(school_data, indent=4, sort_keys=True))
# Out:
# {
#     "numberOfPages": 1,
#     "numberOfSchools": 4,
#     "schoolList": [
#         {
#             "address": {
#                 "city": "Smithville",
#                 "cityURL": "https://www.schooldigger.com/go/TX/city/Smithville/search.aspx",
#                 "html": "403 SW 4th St<br />Smithville, TX 78957-0479",
#                 "latLong": {
#                     "latitude": 30.003756,
#                     "longitude": -97.165861
#                 },
#                 "state": "TX",
#                 "stateFull": "Texas",
#                 "street": "403 SW 4th St",
#                 "zip": "78957",
#                 "zip4": "0479",
#                 "zipURL": "https://www.schooldigger.com/go/TX/zip/78957/search.aspx"
#             },
#             "county": {
#                 "countyName": "Bastrop County",
#                 "countyURL": "https://www.schooldigger.com/go/TX/county/Bastrop+County/search.aspx"
#             },
#             "district": {
#                 "districtID": "4840550",
#                 "districtName": "Smithville Independent School District (ISD)",
#                 "rankURL": "https://www.schooldigger.com/go/TX/districtrank.aspx",
#                 "url": "https://www.schooldigger.com/go/TX/district/40550/search.aspx"
#             },
#             "hasBoundary": false,
#             "highGrade": "K",
#             "isCharterSchool": "No",
#             "isMagnetSchool": "No",
#             "isPrivate": false,
#             "isTitleISchool": "Yes",
#             "isTitleISchoolwideSchool": "No",
#             "isVirtualSchool": "(n/a)",
#             "lowGrade": "PK",
#             "phone": "(512) 237-2519",
#             "privateCoed": null,
#             "privateDays": null,
#             "privateHasLibrary": null,
#             "privateHours": null,
#             "privateOrientation": null,
#             "rankHistory": null,
#             "rankMovement": null,
#             "schoolLevel": "Elementary",
#             "schoolName": "Brown Pri",
#             "schoolYearlyDetails": [
#                 {
#                     "numberOfStudents": 191,
#                     "numberofAfricanAmericanStudents": 15,
#                     "numberofAsianStudents": 0,
#                     "numberofHispanicStudents": 56,
#                     "numberofIndianStudents": 0,
#                     "numberofPacificIslanderStudents": 0,
#                     "numberofTwoOrMoreRaceStudents": 12,
#                     "numberofUnspecifiedRaceStudents": null,
#                     "numberofWhiteStudents": 108,
#                     "percentFreeDiscLunch": 52.36,
#                     "percentofAfricanAmericanStudents": 7.85,
#                     "percentofAsianStudents": 0.0,
#                     "percentofHispanicStudents": 29.32,
#                     "percentofIndianStudents": 0.0,
#                     "percentofPacificIslanderStudents": 0.0,
#                     "percentofTwoOrMoreRaceStudents": 6.28,
#                     "percentofUnspecifiedRaceStudents": null,
#                     "percentofWhiteStudents": 56.54,
#                     "pupilTeacherRatio": 18.5,
#                     "teachersFulltime": 10.3,
#                     "year": 2022
#                 },
#                 {
#                     "numberOfStudents": 409,
#                     "numberofAfricanAmericanStudents": 22,
#                     "numberofAsianStudents": 1,
#                     "numberofHispanicStudents": 140,
#                     "numberofIndianStudents": 0,
#                     "numberofPacificIslanderStudents": 0,
#                     "numberofTwoOrMoreRaceStudents": 24,
#                     "numberofUnspecifiedRaceStudents": null,
#                     "numberofWhiteStudents": 222,
#                     "percentFreeDiscLunch": 61.12,
#                     "percentofAfricanAmericanStudents": 5.38,
#                     "percentofAsianStudents": 0.24,
#                     "percentofHispanicStudents": 34.23,
#                     "percentofIndianStudents": 0.0,
#                     "percentofPacificIslanderStudents": 0.0,
#                     "percentofTwoOrMoreRaceStudents": 5.87,
#                     "percentofUnspecifiedRaceStudents": null,
#                     "percentofWhiteStudents": 54.28,
#                     "pupilTeacherRatio": 14.8,
#                     "teachersFulltime": 27.4,
#                     "year": 2021
#                 }
#             ],
#             "schoolid": "484055004588",
#             "url": "https://www.schooldigger.com/go/TX/schools/4055004588/school.aspx",
#             "urlCompare": "https://www.schooldigger.com/go/TX/schools/4055004588/search.aspx"
#         },
#         {
#             "address": {
#                 "city": "Smithville",
#                 "cityURL": "https://www.schooldigger.com/go/TX/city/Smithville/search.aspx",
#                 "html": "800 Bishop St<br />Smithville, TX 78957-0479",
#                 "latLong": {
#                     "latitude": 30.008766,
#                     "longitude": -97.149086
#                 },
#                 "state": "TX",
#                 "stateFull": "Texas",
#                 "street": "800 Bishop St",
#                 "zip": "78957",
#                 "zip4": "0479",
#                 "zipURL": "https://www.schooldigger.com/go/TX/zip/78957/search.aspx"
#             },
#             "county": {
#                 "countyName": "Bastrop County",
#                 "countyURL": "https://www.schooldigger.com/go/TX/county/Bastrop+County/search.aspx"
#             },
#             "district": {
#                 "districtID": "4840550",
#                 "districtName": "Smithville Independent School District (ISD)",
#                 "rankURL": "https://www.schooldigger.com/go/TX/districtrank.aspx",
#                 "url": "https://www.schooldigger.com/go/TX/district/40550/search.aspx"
#             },
#             "hasBoundary": false,
#             "highGrade": "5",
#             "isCharterSchool": "No",
#             "isMagnetSchool": "No",
#             "isPrivate": false,
#             "isTitleISchool": "Yes",
#             "isTitleISchoolwideSchool": "No",
#             "isVirtualSchool": "(n/a)",
#             "lowGrade": "1",
#             "phone": "(512) 237-2406",
#             "privateCoed": null,
#             "privateDays": null,
#             "privateHasLibrary": null,
#             "privateHours": null,
#             "privateOrientation": null,
#             "rankHistory": [
#                 {
#                     "averageStandardScore": 48.2432,
#                     "rank": 2257,
#                     "rankLevel": "Elementary",
#                     "rankOf": 4581,
#                     "rankStars": 3,
#                     "rankStatewidePercentage": 50.73,
#                     "year": 2022
#                 },
#                 {
#                     "averageStandardScore": 69.01338,
#                     "rank": 1162,
#                     "rankLevel": "Elementary",
#                     "rankOf": 4578,
#                     "rankStars": 4,
#                     "rankStatewidePercentage": 74.62,
#                     "year": 2021
#                 }
#             ],
#             "rankMovement": -1095,
#             "schoolLevel": "Elementary",
#             "schoolName": "Smithville Elementary",
#             "schoolYearlyDetails": [
#                 {
#                     "numberOfStudents": 635,
#                     "numberofAfricanAmericanStudents": 39,
#                     "numberofAsianStudents": 4,
#                     "numberofHispanicStudents": 223,
#                     "numberofIndianStudents": 1,
#                     "numberofPacificIslanderStudents": 1,
#                     "numberofTwoOrMoreRaceStudents": 25,
#                     "numberofUnspecifiedRaceStudents": null,
#                     "numberofWhiteStudents": 342,
#                     "percentFreeDiscLunch": 50.55,
#                     "percentofAfricanAmericanStudents": 6.14,
#                     "percentofAsianStudents": 0.63,
#                     "percentofHispanicStudents": 35.12,
#                     "percentofIndianStudents": 0.16,
#                     "percentofPacificIslanderStudents": 0.16,
#                     "percentofTwoOrMoreRaceStudents": 3.94,
#                     "percentofUnspecifiedRaceStudents": null,
#                     "percentofWhiteStudents": 53.86,
#                     "pupilTeacherRatio": 14.2,
#                     "teachersFulltime": 44.7,
#                     "year": 2022
#                 },
#                 {
#                     "numberOfStudents": 353,
#                     "numberofAfricanAmericanStudents": 23,
#                     "numberofAsianStudents": 7,
#                     "numberofHispanicStudents": 135,
#                     "numberofIndianStudents": 1,
#                     "numberofPacificIslanderStudents": 0,
#                     "numberofTwoOrMoreRaceStudents": 12,
#                     "numberofUnspecifiedRaceStudents": null,
#                     "numberofWhiteStudents": 175,
#                     "percentFreeDiscLunch": 57.79,
#                     "percentofAfricanAmericanStudents": 6.52,
#                     "percentofAsianStudents": 1.98,
#                     "percentofHispanicStudents": 38.24,
#                     "percentofIndianStudents": 0.28,
#                     "percentofPacificIslanderStudents": 0.0,
#                     "percentofTwoOrMoreRaceStudents": 3.4,
#                     "percentofUnspecifiedRaceStudents": null,
#                     "percentofWhiteStudents": 49.58,
#                     "pupilTeacherRatio": 12.6,
#                     "teachersFulltime": 27.9,
#                     "year": 2021
#                 }
#             ],
#             "schoolid": "484055004589",
#             "url": "https://www.schooldigger.com/go/TX/schools/4055004589/school.aspx",
#             "urlCompare": "https://www.schooldigger.com/go/TX/schools/4055004589/search.aspx"
#         },
#         {
#             "address": {
#                 "city": "Smithville",
#                 "cityURL": "https://www.schooldigger.com/go/TX/city/Smithville/search.aspx",
#                 "html": "285 Hwy 95<br />Smithville, TX 78957-0479",
#                 "latLong": {
#                     "latitude": 29.998,
#                     "longitude": -97.1662
#                 },
#                 "state": "TX",
#                 "stateFull": "Texas",
#                 "street": "285 Hwy 95",
#                 "zip": "78957",
#                 "zip4": "0479",
#                 "zipURL": "https://www.schooldigger.com/go/TX/zip/78957/search.aspx"
#             },
#             "county": {
#                 "countyName": "Bastrop County",
#                 "countyURL": "https://www.schooldigger.com/go/TX/county/Bastrop+County/search.aspx"
#             },
#             "district": {
#                 "districtID": "4840550",
#                 "districtName": "Smithville Independent School District (ISD)",
#                 "rankURL": "https://www.schooldigger.com/go/TX/districtrank.aspx",
#                 "url": "https://www.schooldigger.com/go/TX/district/40550/search.aspx"
#             },
#             "hasBoundary": false,
#             "highGrade": "12",
#             "isCharterSchool": "No",
#             "isMagnetSchool": "No",
#             "isPrivate": false,
#             "isTitleISchool": "Yes",
#             "isTitleISchoolwideSchool": "No",
#             "isVirtualSchool": "(n/a)",
#             "lowGrade": "9",
#             "phone": "(512) 237-2451",
#             "privateCoed": null,
#             "privateDays": null,
#             "privateHasLibrary": null,
#             "privateHours": null,
#             "privateOrientation": null,
#             "rankHistory": [
#                 {
#                     "averageStandardScore": 40.1801,
#                     "rank": 1111,
#                     "rankLevel": "High",
#                     "rankOf": 1876,
#                     "rankStars": 2,
#                     "rankStatewidePercentage": 40.78,
#                     "year": 2022
#                 },
#                 {
#                     "averageStandardScore": 49.62314,
#                     "rank": 896,
#                     "rankLevel": "High",
#                     "rankOf": 1861,
#                     "rankStars": 3,
#                     "rankStatewidePercentage": 51.85,
#                     "year": 2021
#                 }
#             ],
#             "rankMovement": -215,
#             "schoolLevel": "High",
#             "schoolName": "Smithville High School",
#             "schoolYearlyDetails": [
#                 {
#                     "numberOfStudents": 570,
#                     "numberofAfricanAmericanStudents": 42,
#                     "numberofAsianStudents": 3,
#                     "numberofHispanicStudents": 180,
#                     "numberofIndianStudents": 0,
#                     "numberofPacificIslanderStudents": 0,
#                     "numberofTwoOrMoreRaceStudents": 22,
#                     "numberofUnspecifiedRaceStudents": null,
#                     "numberofWhiteStudents": 323,
#                     "percentFreeDiscLunch": 40.7,
#                     "percentofAfricanAmericanStudents": 7.37,
#                     "percentofAsianStudents": 0.53,
#                     "percentofHispanicStudents": 31.58,
#                     "percentofIndianStudents": 0.0,
#                     "percentofPacificIslanderStudents": 0.0,
#                     "percentofTwoOrMoreRaceStudents": 3.86,
#                     "percentofUnspecifiedRaceStudents": null,
#                     "percentofWhiteStudents": 56.67,
#                     "pupilTeacherRatio": 13.2,
#                     "teachersFulltime": 42.8,
#                     "year": 2022
#                 },
#                 {
#                     "numberOfStudents": 584,
#                     "numberofAfricanAmericanStudents": 47,
#                     "numberofAsianStudents": 3,
#                     "numberofHispanicStudents": 171,
#                     "numberofIndianStudents": 2,
#                     "numberofPacificIslanderStudents": 1,
#                     "numberofTwoOrMoreRaceStudents": 21,
#                     "numberofUnspecifiedRaceStudents": null,
#                     "numberofWhiteStudents": 339,
#                     "percentFreeDiscLunch": 51.88,
#                     "percentofAfricanAmericanStudents": 8.05,
#                     "percentofAsianStudents": 0.51,
#                     "percentofHispanicStudents": 29.28,
#                     "percentofIndianStudents": 0.34,
#                     "percentofPacificIslanderStudents": 0.17,
#                     "percentofTwoOrMoreRaceStudents": 3.6,
#                     "percentofUnspecifiedRaceStudents": null,
#                     "percentofWhiteStudents": 58.05,
#                     "pupilTeacherRatio": 13.5,
#                     "teachersFulltime": 43.0,
#                     "year": 2021
#                 }
#             ],
#             "schoolid": "484055004590",
#             "url": "https://www.schooldigger.com/go/TX/schools/4055004590/school.aspx",
#             "urlCompare": "https://www.schooldigger.com/go/TX/schools/4055004590/search.aspx"
#         },
#         {
#             "address": {
#                 "city": "Smithville",
#                 "cityURL": "https://www.schooldigger.com/go/TX/city/Smithville/search.aspx",
#                 "html": "287 Hwy 95 S<br />Smithville, TX 78957-1110",
#                 "latLong": {
#                     "latitude": 29.996394,
#                     "longitude": -97.166314
#                 },
#                 "state": "TX",
#                 "stateFull": "Texas",
#                 "street": "287 Hwy 95 S",
#                 "zip": "78957",
#                 "zip4": "1110",
#                 "zipURL": "https://www.schooldigger.com/go/TX/zip/78957/search.aspx"
#             },
#             "county": {
#                 "countyName": "Bastrop County",
#                 "countyURL": "https://www.schooldigger.com/go/TX/county/Bastrop+County/search.aspx"
#             },
#             "district": {
#                 "districtID": "4840550",
#                 "districtName": "Smithville Independent School District (ISD)",
#                 "rankURL": "https://www.schooldigger.com/go/TX/districtrank.aspx",
#                 "url": "https://www.schooldigger.com/go/TX/district/40550/search.aspx"
#             },
#             "hasBoundary": false,
#             "highGrade": "8",
#             "isCharterSchool": "No",
#             "isMagnetSchool": "No",
#             "isPrivate": false,
#             "isTitleISchool": "Yes",
#             "isTitleISchoolwideSchool": "No",
#             "isVirtualSchool": "(n/a)",
#             "lowGrade": "6",
#             "phone": "(512) 237-2407",
#             "privateCoed": null,
#             "privateDays": null,
#             "privateHasLibrary": null,
#             "privateHours": null,
#             "privateOrientation": null,
#             "rankHistory": [
#                 {
#                     "averageStandardScore": 40.41651,
#                     "rank": 1320,
#                     "rankLevel": "Middle",
#                     "rankOf": 2254,
#                     "rankStars": 2,
#                     "rankStatewidePercentage": 41.44,
#                     "year": 2022
#                 },
#                 {
#                     "averageStandardScore": 50.78474,
#                     "rank": 1008,
#                     "rankLevel": "Middle",
#                     "rankOf": 2252,
#                     "rankStars": 3,
#                     "rankStatewidePercentage": 55.24,
#                     "year": 2021
#                 }
#             ],
#             "rankMovement": -312,
#             "schoolLevel": "Middle",
#             "schoolName": "Smithville J H",
#             "schoolYearlyDetails": [
#                 {
#                     "numberOfStudents": 392,
#                     "numberofAfricanAmericanStudents": 26,
#                     "numberofAsianStudents": 3,
#                     "numberofHispanicStudents": 147,
#                     "numberofIndianStudents": 0,
#                     "numberofPacificIslanderStudents": 0,
#                     "numberofTwoOrMoreRaceStudents": 16,
#                     "numberofUnspecifiedRaceStudents": null,
#                     "numberofWhiteStudents": 200,
#                     "percentFreeDiscLunch": 42.6,
#                     "percentofAfricanAmericanStudents": 6.63,
#                     "percentofAsianStudents": 0.77,
#                     "percentofHispanicStudents": 37.5,
#                     "percentofIndianStudents": 0.0,
#                     "percentofPacificIslanderStudents": 0.0,
#                     "percentofTwoOrMoreRaceStudents": 4.08,
#                     "percentofUnspecifiedRaceStudents": null,
#                     "percentofWhiteStudents": 51.02,
#                     "pupilTeacherRatio": 13.1,
#                     "teachersFulltime": 29.8,
#                     "year": 2022
#                 },
#                 {
#                     "numberOfStudents": 407,
#                     "numberofAfricanAmericanStudents": 26,
#                     "numberofAsianStudents": 1,
#                     "numberofHispanicStudents": 148,
#                     "numberofIndianStudents": 0,
#                     "numberofPacificIslanderStudents": 0,
#                     "numberofTwoOrMoreRaceStudents": 17,
#                     "numberofUnspecifiedRaceStudents": null,
#                     "numberofWhiteStudents": 215,
#                     "percentFreeDiscLunch": 57.0,
#                     "percentofAfricanAmericanStudents": 6.39,
#                     "percentofAsianStudents": 0.25,
#                     "percentofHispanicStudents": 36.36,
#                     "percentofIndianStudents": 0.0,
#                     "percentofPacificIslanderStudents": 0.0,
#                     "percentofTwoOrMoreRaceStudents": 4.18,
#                     "percentofUnspecifiedRaceStudents": null,
#                     "percentofWhiteStudents": 52.83,
#                     "pupilTeacherRatio": 11.5,
#                     "teachersFulltime": 35.2,
#                     "year": 2021
#                 }
#             ],
#             "schoolid": "484055004591",
#             "url": "https://www.schooldigger.com/go/TX/schools/4055004591/school.aspx",
#             "urlCompare": "https://www.schooldigger.com/go/TX/schools/4055004591/search.aspx"
#         }
#     ]
# }

# %%
for zipcode in county_dictionary['Bastrop County']:
    for school in zipcode_dictionary[zipcode]['schoolList']:
        try:
            if  school['rankHistory']!=None:
                zipcodes.append(zipcode)
                schoolNames.append(school['schoolName'])
                rankMovements.append(school['rankMovement'])
                lats.append(school['address']['latLong']['latitude'])
                longs.append(school['address']['latLong']['longitude'])
                countyNames.append(school['county']['countyName'])
                rankLevels.append(school['rankHistory'][0]['rankLevel'])
                if (school['rankHistory'][0]['year']==2022):
                        averageStandardScores22.append(school['rankHistory'][0]['averageStandardScore'])
                        ranks22.append(school['rankHistory'][0]['rank'])
                        rankStatewidePercentages22.append(school['rankHistory'][0]['rankStatewidePercentage'])
                if(school['rankHistory'][1]['year']==2021):
                        averageStandardScores21.append(school['rankHistory'][1]['averageStandardScore'])
                        ranks21.append(school['rankHistory'][1]['rank'])
                        rankStatewidePercentages21.append(school['rankHistory'][1]['rankStatewidePercentage']) 
                else:
                    pass
            else:
                pass
        except:
            pass

# %%
test_df=pd.DataFrame({'zipcode':zipcodes,'schoolNames':schoolNames,'rankMovements':rankMovements,'lats':lats,'longs':longs,'countyNames':countyNames,'rankLevels':rankLevels,
                      'averageStandardScores22':averageStandardScores22,'ranks22':ranks22,'rankStatewidePercentages22':rankStatewidePercentages22,
                      'averageStandardScores21':averageStandardScores21,'ranks21':ranks21,'rankStatewidePercentages21':rankStatewidePercentages21})
#print(json.dumps(zipcode_dictionary[78717], indent=4, sort_keys=True))
test_df.head(50)
# Out:
#     zipcode                        schoolNames  rankMovements       lats  \
# 0     78602                Bastrop High School           -105  30.117982
# 1     78602                     Bastrop Middle            -20  30.112805
# 2     78602              Bluebonnet Elementary           -755  30.132427
# 3     78602  Colorado River Collegiate Academy             42  30.117420
# 4     78602                   Emile Elementary            367  30.106769
# 5     78612             Cedar Creek Elementary           -199  30.084121
# 6     78612            Cedar Creek High School           -343  30.138350
# 7     78612                 Cedar Creek Middle            -94  30.095130
# 8     78621     Booker T Washington Elementary            -79  30.341800
# 9     78621                   Elgin Elementary            253  30.349566
# 10    78621                  Elgin High School           -219  30.366377
# 11    78621                       Elgin Middle             44  30.358686
# 12    78621                  Neidig Elementary          -1221  30.360600
# 13    78621                Phoenix High School            -17  30.367370
# 14    78650                  McDade Elementary          -1186  30.283488
# 15    78650                 McDade High School           -202  30.283488
# 16    78662                Red Rock Elementary            151  29.958825
# 17    78957              Smithville Elementary          -1095  30.008766
# 18    78957             Smithville High School           -215  29.998000
# 19    78957                     Smithville J H           -312  29.996394
# 20    78602                Bastrop High School           -105  30.117982
# 21    78602                     Bastrop Middle            -20  30.112805
# 22    78602              Bluebonnet Elementary           -755  30.132427
# 23    78602  Colorado River Collegiate Academy             42  30.117420
# 24    78602                   Emile Elementary            367  30.106769
# 25    78612             Cedar Creek Elementary           -199  30.084121
# 26    78612            Cedar Creek High School           -343  30.138350
# 27    78612                 Cedar Creek Middle            -94  30.095130
# 28    78621     Booker T Washington Elementary            -79  30.341800
# 29    78621                   Elgin Elementary            253  30.349566
# 30    78621                  Elgin High School           -219  30.366377
# 31    78621                       Elgin Middle             44  30.358686
# 32    78621                  Neidig Elementary          -1221  30.360600
# 33    78621                Phoenix High School            -17  30.367370
# 34    78650                  McDade Elementary          -1186  30.283488
# 35    78650                 McDade High School           -202  30.283488
# 36    78662                Red Rock Elementary            151  29.958825
# 37    78957              Smithville Elementary          -1095  30.008766
# 38    78957             Smithville High School           -215  29.998000
# 39    78957                     Smithville J H           -312  29.996394
#
#         longs     countyNames  rankLevels  averageStandardScores22  ranks22  \
# 0  -97.311598  Bastrop County        High                 30.12612     1344
# 1  -97.343010  Bastrop County      Middle                 33.76330     1514
# 2  -97.430100  Bastrop County  Elementary                 17.34277     4081
# 3  -97.315688  Bastrop County        High                 93.07890       23
# 4  -97.310006  Bastrop County  Elementary                 42.61116     2580
# 5  -97.500006  Bastrop County  Elementary                 10.13308     4399
# 6  -97.471641  Bastrop County        High                 20.54056     1527
# 7  -97.479935  Bastrop County      Middle                 18.41832     1964
# 8  -97.365400  Bastrop County  Elementary                 12.69529     4302
# 9  -97.379744  Bastrop County  Elementary                 21.45919     3859
# 10 -97.404222   Travis County        High                 19.42761     1552
# 11 -97.386889  Bastrop County      Middle                 21.23652     1900
# 12 -97.408300   Travis County  Elementary                 19.20317     3988
# 13 -97.405940   Travis County        High                  1.37884     1874
# 14 -97.239533  Bastrop County  Elementary                 33.97164     3125
# 15 -97.239533  Bastrop County        High                 33.31548     1269
# 16 -97.451251  Bastrop County  Elementary                 19.66732     3963
# 17 -97.149086  Bastrop County  Elementary                 48.24320     2257
# 18 -97.166200  Bastrop County        High                 40.18010     1111
# 19 -97.166314  Bastrop County      Middle                 40.41651     1320
# 20 -97.311598  Bastrop County        High                 30.12612     1344
# 21 -97.343010  Bastrop County      Middle                 33.76330     1514
# 22 -97.430100  Bastrop County  Elementary                 17.34277     4081
# 23 -97.315688  Bastrop County        High                 93.07890       23
# 24 -97.310006  Bastrop County  Elementary                 42.61116     2580
# 25 -97.500006  Bastrop County  Elementary                 10.13308     4399
# 26 -97.471641  Bastrop County        High                 20.54056     1527
# 27 -97.479935  Bastrop County      Middle                 18.41832     1964
# 28 -97.365400  Bastrop County  Elementary                 12.69529     4302
# 29 -97.379744  Bastrop County  Elementary                 21.45919     3859
# 30 -97.404222   Travis County        High                 19.42761     1552
# 31 -97.386889  Bastrop County      Middle                 21.23652     1900
# 32 -97.408300   Travis County  Elementary                 19.20317     3988
# 33 -97.405940   Travis County        High                  1.37884     1874
# 34 -97.239533  Bastrop County  Elementary                 33.97164     3125
# 35 -97.239533  Bastrop County        High                 33.31548     1269
# 36 -97.451251  Bastrop County  Elementary                 19.66732     3963
# 37 -97.149086  Bastrop County  Elementary                 48.24320     2257
# 38 -97.166200  Bastrop County        High                 40.18010     1111
# 39 -97.166314  Bastrop County      Middle                 40.41651     1320
#
#     rankStatewidePercentages22  averageStandardScores21  ranks21  \
# 0                        28.36                 34.16063     1239
# 1                        32.83                 33.31015     1494
# 2                        10.91                 27.75586     3326
# 3                        98.77                 89.02025       65
# 4                        43.68                 33.24658     2947
# 5                         3.97                 15.15267     4200
# 6                        18.60                 36.99134     1184
# 7                        12.87                 20.35392     1870
# 8                         6.09                 14.83249     4223
# 9                        15.76                 16.50551     4112
# 10                       17.27                 29.37800     1333
# 11                       15.71                 17.91220     1944
# 12                       12.94                 36.32757     2767
# 13                        0.11                  1.53300     1857
# 14                       31.78                 51.99912     1939
# 15                       32.36                 42.42294     1067
# 16                       13.49                 16.48424     4114
# 17                       50.73                 69.01338     1162
# 18                       40.78                 49.62314      896
# 19                       41.44                 50.78474     1008
# 20                       28.36                 34.16063     1239
# 21                       32.83                 33.31015     1494
# 22                       10.91                 27.75586     3326
# 23                       98.77                 89.02025       65
# 24                       43.68                 33.24658     2947
# 25                        3.97                 15.15267     4200
# 26                       18.60                 36.99134     1184
# 27                       12.87                 20.35392     1870
# 28                        6.09                 14.83249     4223
# 29                       15.76                 16.50551     4112
# 30                       17.27                 29.37800     1333
# 31                       15.71                 17.91220     1944
# 32                       12.94                 36.32757     2767
# 33                        0.11                  1.53300     1857
# 34                       31.78                 51.99912     1939
# 35                       32.36                 42.42294     1067
# 36                       13.49                 16.48424     4114
# 37                       50.73                 69.01338     1162
# 38                       40.78                 49.62314      896
# 39                       41.44                 50.78474     1008
#
#     rankStatewidePercentages21
# 0                        33.42
# 1                        33.66
# 2                        27.35
# 3                        96.51
# 4                        35.63
# 5                         8.26
# 6                        36.38
# 7                        16.96
# 8                         7.75
# 9                        10.18
# 10                       28.37
# 11                       13.68
# 12                       39.56
# 13                        0.21
# 14                       57.65
# 15                       42.67
# 16                       10.14
# 17                       74.62
# 18                       51.85
# 19                       55.24
# 20                       33.42
# 21                       33.66
# 22                       27.35
# 23                       96.51
# 24                       35.63
# 25                        8.26
# 26                       36.38
# 27                       16.96
# 28                        7.75
# 29                       10.18
# 30                       28.37
# 31                       13.68
# 32                       39.56
# 33                        0.21
# 34                       57.65
# 35                       42.67
# 36                       10.14
# 37                       74.62
# 38                       51.85
# 39                       55.24

# %%
# Out:
# Cedar Valley Middle
# 45
# 30.492108
# -97.734198
# Williamson County
# 96.36768
# 48
# 97.87
# 2022
# 93.4777
# 93
# 97.87
# 2021
# Middle
# Elsa England Elementary
# 39
# 30.493608
# -97.750879
# Williamson County
# 98.16131
# 51
# 98.89
# 2022
# 97.95845
# 90
# 98.89
# 2021
# Elementary
# Patsy Sommer Elementary
# 3
# 30.504541
# -97.751946
# Williamson County
# 98.84738
# 24
# 99.48
# 2022
# 99.35792
# 27
# 99.48
# 2021
# Elementary
# Pearson Ranch Middle
# -16
# 30.496193
# -97.749922
# Williamson County
# 95.28929
# 66
# 97.07
# 2022
# 96.54958
# 50
# 97.07
# 2021
# Middle
# Rutledge Elementary
# -90
# 30.49792
# -97.79333
# Williamson County
# 89.62557
# 369
# 91.94
# 2022
# 93.02407
# 279
# 91.94
# 2021
# Elementary

# %%
#I will need lat,Long, rankHistory{{'year': 2021,'rank': 2947,'rankOf': 4578,'rankStars': 2,'rankLevel': 'Elementary','rankStatewidePercentage': 35.63,'averageStandardScore': 33.24658}}, 'county': {'countyName': 'Bastrop County', rankMovement

print(len(zipcode_dictionary))
# Out:
# 117

# %%
            print(school['schoolName'])
            print(school['rankMovement'])
            print(school['address']['latLong']['latitude'])
            print(school['address']['latLong']['longitude'])
            print(school['county']['countyName'])
            print(school['rankHistory'][0]['averageStandardScore'])
            print(school['rankHistory'][0]['rank'])
            print(school['rankHistory'][0]['rankStatewidePercentage'])
            print(school['rankHistory'][0]['year'])
            print(school['rankHistory'][1]['averageStandardScore'])
            print(school['rankHistory'][1]['rank'])
            print(school['rankHistory'][0]['rankStatewidePercentage'])
            print(school['rankHistory'][1]['year'])
            print(school['rankHistory'][0]['rankLevel'])
