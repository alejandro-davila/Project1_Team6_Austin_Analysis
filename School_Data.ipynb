base_url='https://api.schooldigger.com/v2.0/schools?st=TX'


zipcodes=[]
schoolNames=[]
rankMovements=[]
lats=[]
longs=[]
countyNames=[]
rankLevels=[]
averageStandardScores22=[]
averageStandardScores21=[]
ranks22=[]
ranks21=[]
rankStatewidePercentages22=[]
rankStatewidePercentages21=[]

# %%
for zipcode in zipcode_dictionary:
    request_url=f'{base_url}&zip={zipcode}&appID={school_digger_app_id}&appKey={school_digger_key}'
    response = requests.get(request_url)
    school_data=(response.json())
    zipcode_dictionary[zipcode]=school_data
#print(json.dumps(school_data, indent=4, sort_keys=True))

# %%
zipcodes=[]
schoolNames=[]
rankMovements=[]
lats=[]
longs=[]
countyNames=[]
rankLevels=[]
averageStandardScores22=[]
averageStandardScores21=[]
ranks22=[]
ranks21=[]
rankStatewidePercentages22=[]
rankStatewidePercentages21=[]
for zipcode in zipcode_dictionary: 
    #print(zipcode_dictionary[zipcode])
    #print(zipcode)
 
        for school in zipcode_dictionary[zipcode]['schoolList']:
                if  school['rankHistory']!=None:
                    try:
                        zipcodes.append(zipcode)
                    except:
                        zipcodes.append(None)
                    try:
                        schoolNames.append(school['schoolName'])
                    except:
                        schoolNames.append(None)
                    try:
                        rankMovements.append(school['rankMovement'])
                    except:
                        rankMovements.append(None)
                    try:
                        lats.append(school['address']['latLong']['latitude'])
                    except:
                        lats.append(None)
                    try:
                        longs.append(school['address']['latLong']['longitude'])
                    except:
                        longs.append(None)
                    try:
                        countyNames.append(school['county']['countyName'])   
                    except:
                        countyNames.append(None)    
                    try:
                        rankLevels.append(school['rankHistory'][0]['rankLevel'])
                    except:
                        rankLevels.append(None)
                    try:
                        if (school['rankHistory'][0]['year']==2022):
                                averageStandardScores22.append(school['rankHistory'][0]['averageStandardScore'])
                                ranks22.append(school['rankHistory'][0]['rank'])
                                rankStatewidePercentages22.append(school['rankHistory'][0]['rankStatewidePercentage'])
                    except:
                            averageStandardScores22.append(None)
                            ranks22.append(None)
                            rankStatewidePercentages22.append(None)
                    try:
                        if(school['rankHistory'][1]['year']==2021):
                                averageStandardScores21.append(school['rankHistory'][1]['averageStandardScore'])
                                ranks21.append(school['rankHistory'][1]['rank'])
                                rankStatewidePercentages21.append(school['rankHistory'][1]['rankStatewidePercentage']) 
                    except:
                            averageStandardScores21.append(None)
                            ranks21.append(None)
                            rankStatewidePercentages21.append(None)
                else:
                    pass

# %%
test_df=pd.DataFrame({'zipcode':zipcodes,'schoolNames':schoolNames,'rankMovements':rankMovements,'lats':lats,'longs':longs,'countyNames':countyNames,'rankLevels':rankLevels,
                      'averageStandardScores22':averageStandardScores22,'ranks22':ranks22,'rankStatewidePercentages22':rankStatewidePercentages22,
                      'averageStandardScores21':averageStandardScores21,'ranks21':ranks21,'rankStatewidePercentages21':rankStatewidePercentages21})
#print(json.dumps(zipcode_dictionary[78717], indent=4, sort_keys=True))
test_df.head(50)
# Out:
#     zipcode                        schoolNames  rankMovements       lats  \
# 0     78602                Bastrop High School         -105.0  30.117982
# 1     78602                     Bastrop Middle          -20.0  30.112805
# 2     78602              Bluebonnet Elementary         -755.0  30.132427
# 9  -97.379744  Bastrop County  Elementary                 21.45919     3859
# 10 -97.404222   Travis County        High                 19.42761     1552
# 11 -97.386889  Bastrop County      Middle                 21.23652     1900
# 12 -97.408300   Travis County  Elementary                 19.20317     3988
# 13 -97.405940   Travis County        High                  1.37884     1874
# 14 -97.239533  Bastrop County  Elementary                 33.97164     3125
# 15 -97.239533  Bastrop County        High                 33.31548     1269
# 16 -97.451251  Bastrop County  Elementary                 19.66732     3963
# 17 -97.149086  Bastrop County  Elementary                 48.24320     2257
# 18 -97.166200  Bastrop County        High                 40.18010     1111
# 19 -97.166314  Bastrop County      Middle                 40.41651     1320
# 20 -97.891158     Hays County        High                  7.31753     1753
# 21 -97.820826     Hays County  Elementary                 68.19921     1220
# 22 -97.896680     Hays County  Elementary                 89.95657      355
# 23 -97.720692   Travis County  Elementary                 34.26617     3106
# 24 -97.824040     Hays County      Middle                 50.88696      989
# 25 -97.873260     Hays County  Elementary                 88.53951      405
# 26 -97.882200     Hays County      Middle                 82.02557      302
# 27 -97.889957     Hays County        High                 61.91350      562
# 28 -97.889800     Hays County        High                 15.11695     1611
# 29 -98.082273     Hays County  Elementary                 81.08988      695
# 30 -98.101321     Hays County        High                 78.91586      211
# 31 -98.115101     Hays County      Middle                 84.03577      248
# 32 -98.114218     Hays County  Elementary                 86.61435      483
# 33 -97.833000     Hays County      Middle                 42.05352     1253
# 34 -97.761941     Hays County  Elementary                 32.96580     3177
# 35 -97.828637     Hays County      Middle                 12.42119     2116
# 36 -97.827346     Hays County  Elementary                 39.47784     2767
# 37 -97.863843     Hays County  Elementary                 41.58080     2646
# 38 -97.863843     Hays County      Middle                 56.38099      828
# 39 -97.878800     Hays County  Elementary                 46.76687     2328
# 40 -97.883800     Hays County  Elementary                 73.77679     1000
# 41 -97.889700     Hays County      Middle                 45.66974     1140
# 42 -97.847630     Hays County        High                 33.72540     1254
# 43 -97.896218     Hays County  Elementary                 61.48820     1536
# 44 -97.941430     Hays County  Elementary                 22.26150     3826
# 45 -97.961547     Hays County  Elementary                 55.85331     1819
# 46 -97.935145     Hays County  Elementary                 22.97839     3785
# 47 -97.937067     Hays County      Middle                 15.06176     2045
# 48 -97.968347     Hays County  Elementary                 58.46797     1678
# 49 -97.945788     Hays County        High                 20.61700     1526
#
#     rankStatewidePercentages22  averageStandardScores21  ranks21  \
# 0                        28.36                 34.16063   1239.0
# 1                        32.83                 33.31015   1494.0
# 2                        10.91                 27.75586   3326.0
# 3                        98.77                 89.02025     65.0
# 4                        43.68                 33.24658   2947.0
# 5                         3.97                 15.15267   4200.0
# 6                        18.60                 36.99134   1184.0
# 7                        12.87                 20.35392   1870.0
# 8                         6.09                 14.83249   4223.0
# 9                        15.76                 16.50551   4112.0
# 10                       17.27                 29.37800   1333.0
# 11                       15.71                 17.91220   1944.0
# 12                       12.94                 36.32757   2767.0
# 13                        0.11                  1.53300   1857.0
# 14                       31.78                 51.99912   1939.0
# 15                       32.36                 42.42294   1067.0
# 16                       13.49                 16.48424   4114.0
# 17                       50.73                 69.01338   1162.0
# 18                       40.78                 49.62314    896.0
# 19                       41.44                 50.78474   1008.0
# 20                        6.56                  9.41800   1707.0
# 21                       73.37                 67.08559   1256.0
# 22                       92.25                 91.42539    340.0
# 23                       32.20                 20.22316   3849.0
# 24                       56.12                 38.02601   1350.0
# 25                       91.16                 92.63022    288.0
# 26                       86.60                 78.32750    340.0
# 27                       70.04                 55.29533    760.0
# 28                       14.13                  9.31527   1709.0
# 29                       84.83                 84.31833    595.0
# 30                       88.75                 78.38444    246.0
# 31                       89.00                 82.34856    272.0
# 32                       89.46                 83.73069    612.0
# 33                       44.41                 26.12148   1712.0
# 34                       30.65                 23.28784   3621.0
# 35                        6.12                 15.72293   2010.0
# 36                       39.60                 33.73840   2915.0
# 37                       42.24                 45.63990   2262.0
# 38                       63.27                 43.53454   1206.0
# 39                       49.18                 54.40953   1809.0
# 40                       78.17                 72.77312   1000.0
# 41                       49.42                 40.43845   1279.0
# 42                       33.16                 32.69169   1264.0
# 43                       66.47                 58.33820   1605.0
# 44                       16.48                 20.57457   3814.0
# 45                       60.29                 52.71735   1899.0
# 46                       17.38                 20.31836   3840.0
# 47                        9.27                 23.72162   1775.0
# 48                       63.37                 56.27536   1713.0
# 49                       18.66                  6.46769   1756.0
#
#     rankStatewidePercentages21
# 0                        33.42
# 1                        33.66
# 2                        27.35
# 3                        96.51
# 4                        35.63
# 5                         8.26
# 6                        36.38
# 7                        16.96
# 8                         7.75
# 9                        10.18
# 10                       28.37
# 11                       13.68
# 12                       39.56
# 13                        0.21
# 14                       57.65
# 15                       42.67
# 16                       10.14
# 17                       74.62
# 18                       51.85
# 19                       55.24
# 20                        8.28
# 21                       72.56
# 22                       92.57
# 23                       15.92
# 24                       40.05
# 25                       93.71
# 26                       84.90
# 27                       59.16
# 28                        8.17
# 29                       87.00
# 30                       86.78
# 31                       87.92
# 32                       86.63
# 33                       23.98
# 34                       20.90
# 35                       10.75
# 36                       36.33
# 37                       50.59
# 38                       46.45
# 39                       60.48
# 40                       78.16
# 41                       43.21
# 42                       32.08
# 43                       64.94
# 44                       16.69
# 45                       58.52
# 46                       16.12
# 47                       21.18
# 48                       62.58
# 49                        5.64

# %%
test_df.to_csv('school_data.csv')

# %%
#I will need lat,Long, rankHistory{{'year': 2021,'rank': 2947,'rankOf': 4578,'rankStars': 2,'rankLevel': 'Elementary','rankStatewidePercentage': 35.63,'averageStandardScore': 33.24658}}, 'county': {'countyName': 'Bastrop County', rankMovement

print(len(zipcode_dictionary))
# Out:
# 117

# %%
            print(school['schoolName'])
            print(school['rankMovement'])
            print(school['address']['latLong']['latitude'])
            print(school['address']['latLong']['longitude'])
            print(school['county']['countyName'])
            print(school['rankHistory'][0]['averageStandardScore'])
            print(school['rankHistory'][0]['rank'])
            print(school['rankHistory'][0]['rankStatewidePercentage'])
            print(school['rankHistory'][0]['year'])
            print(school['rankHistory'][1]['averageStandardScore'])
            print(school['rankHistory'][1]['rank'])
            print(school['rankHistory'][0]['rankStatewidePercentage'])
            print(school['rankHistory'][1]['year'])
            print(school['rankHistory'][0]['rankLevel'])
